# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os, sys
sys.path.append(os.path.abspath('..'))

# %%
df = pd.read_csv('../data/raw/new_hampshire_real_estate_2026.csv')

# %% [markdown]
# ### Structural Audit

# %%
df.head()
# Out:
#             type sub_type                                               text  \
# 0  single_family      NaN  Welcome to this spacious home offering endless...
# 1  single_family      NaN  Quintessential New Hampshire Living with Lake ...
# 2  single_family      NaN  Motivated Seller! Antique cape on three acres ...
# 3  single_family      NaN  Meredith, NH 03253--You won't want to miss thi...
# 4  single_family      NaN  Welcome to 10 Roy Drive, a true gem located in...
#
#    listPrice    sqft  stories  beds  baths  baths_full  baths_full_calc  \
# 0     565000  3520.0      3.0   4.0    3.0         1.0              2.0
# 1     449000  2203.0      2.0   3.0    2.0         2.0              2.0
# 2     209900  1350.0      NaN   2.0    1.0         1.0              1.0
# 3     569000  3684.0      2.0   3.0    3.0         2.0              2.0
# 4     749000  3945.0      2.0   4.0    4.0         2.0              2.0
#
#    garage
# 0     2.0
# 1     2.0
# 2     NaN
# 3     2.0
# 4     2.0

# %%
df.shape
# Out:
# (5009, 11)

# %%
df.duplicated().sum()
# Out:
# np.int64(80)

# %%
df[df['sqft'] == 885.0]
# Out:
#         type sub_type                                               text  \
# 889   condos    condo  Experience the perfect blend of convenience an...
# 1787  condos    condo  Experience the perfect blend of convenience an...
# 1997  condos    condo  Experience the perfect blend of convenience an...
# 3407  condos    condo  Experience the perfect blend of convenience an...
#
#       listPrice   sqft  stories  beds  baths  baths_full  baths_full_calc  \
# 889      275000  885.0      1.0   2.0    1.0         1.0              1.0
# 1787     275000  885.0      1.0   2.0    1.0         1.0              1.0
# 1997     305000  885.0      1.0   2.0    1.0         1.0              1.0
# 3407     275000  885.0      1.0   2.0    1.0         1.0              1.0
#
#       garage
# 889      NaN
# 1787     NaN
# 1997     NaN
# 3407     NaN

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# type                  0
# sub_type           3897
# text                 10
# listPrice             0
# sqft               1039
# stories            1271
# beds               1103
# baths              1124
# baths_full         1306
# baths_full_calc    1131
# garage             2512
# dtype: int64

# %%
df.nunique()
# Out:
# type                  7
# sub_type              2
# text               4812
# listPrice          1205
# sqft               1957
# stories               6
# beds                 18
# baths                16
# baths_full           11
# baths_full_calc      15
# garage               15
# dtype: int64

# %%
df.head(1)
# Out:
#             type sub_type                                               text  \
# 0  single_family      NaN  Welcome to this spacious home offering endless...
#
#    listPrice    sqft  stories  beds  baths  baths_full  baths_full_calc  \
# 0     565000  3520.0      3.0   4.0    3.0         1.0              2.0
#
#    garage
# 0     2.0

# %%
df['type'].value_counts()
# Out:
# type
# single_family    2284
# land             1023
# condos            645
# townhomes         387
# mobile            362
# multi_family      224
# condo               4
# Name: count, dtype: int64

# %%
df['sub_type'].value_counts()
# Out:
# sub_type
# condo        645
# townhouse    387
# Name: count, dtype: int64

# %%
df['stories'].value_counts()
# Out:
# stories
# 2.0    1948
# 1.0    1231
# 3.0     422
# 4.0      55
# 5.0       1
# 6.0       1
# Name: count, dtype: int64

# %%
df['garage'].value_counts()
# Out:
# garage
# 2.0      1295
# 1.0       779
# 3.0       221
# 4.0        68
# 6.0        17
# 5.0        14
# 8.0         9
# 7.0         6
# 10.0        2
# 15.0        1
# 14.0        1
# 24.0        1
# 480.0       1
# 48.0        1
# 21.0        1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4929 entries, 0 to 5008
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   type             4929 non-null   object
#  1   sub_type         1032 non-null   object
#  2   text             4919 non-null   object
#  3   listPrice        4929 non-null   int64
#  4   sqft             3890 non-null   float64
#  5   stories          3658 non-null   float64
#  6   beds             3826 non-null   float64
#  7   baths            3805 non-null   float64
#  8   baths_full       3623 non-null   float64
#  9   baths_full_calc  3798 non-null   float64
#  10  garage           2417 non-null   float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 462.1+ KB

# %% [markdown]
# ## Split Data

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=['listPrice'])
y = df['listPrice']

X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2, random_state=42)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((3943, 10), (3943,), (986, 10), (986,))

# %% [markdown]
# ## Numerical Audit inspection

# %%
from src.numerical_audit import numerical_audit

# %%
numerical_audit(df)
# Out:
#        column_name data_type  missing_count  missing_rate           mean  \
# 0        listPrice     int64              0           0.0  619223.023158
# 1             sqft   float64           1079          22.0    2127.439440
# 2          stories   float64           1312          26.0       1.810116
# 3             beds   float64           1143          23.0       3.041904
# 4            baths   float64           1164          23.0       2.450975
# 5       baths_full   float64           1346          27.0       1.636910
# 6  baths_full_calc   float64           1171          23.0       1.990099
# 7           garage   float64           2561          51.0       2.147467
#
#      median  min_val     max_val       skew  outlier_count  outlier_rate
# 0  459000.0    450.0  16950000.0   6.542671            351          7.01
# 1    1789.0    240.0     49502.0  12.281305            178          4.53
# 2       2.0      1.0         6.0   0.608489             57          1.54
# 3       3.0      0.0        27.0   3.793295             49          1.27
# 4       2.0      0.0        17.0   2.592571            159          4.14
# 5       1.0      1.0        12.0   3.366213            124          3.39
# 6       2.0      1.0        15.0   3.581445            202          5.26
# 7       2.0      1.0       480.0  47.778257            122          4.98
